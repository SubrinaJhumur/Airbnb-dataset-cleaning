# %%
# import pandas for data cleaning and data loading
# the link of the dataset is: https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata
import pandas as pd

# %%
#data loading in the notebook
data=pd.read_csv(r'C:\Users\User\Desktop\Airbnb_Open_Data.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1852\3049675858.py:2: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv(r'C:\Users\User\Desktop\Airbnb_Open_Data.csv')

# %%
#first 3 rows of the dataset
data.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
#total number of rows and columns in the dataset
data.shape
# Out:
# (102599, 26)

# %%
# the columns present in the dataset
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
#dataset information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
"""deleting redunt columns.
    renaming the columns.
    dropping duplicates.
    cleaning individual column.
    remove the nan values from the dataset.
    check for some more informations."""
# Out:
# 'deleting redunt columns.\n    renaming the columns.\n    dropping duplicates.\n    cleaning individual column.\n    remove the nan values from the dataset.\n    check for some more informations.'

# %%
#is there any missing values present in the dataset
data.isnull().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified               289
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %%
# columns present in the dataset
percent_missing = data.isnull().sum() * 100 / len(data)

# %%
#see the percent of data missing
percent_missing
# Out:
# id                                 0.000000
# NAME                               0.243667
# host id                            0.000000
# host_identity_verified             0.281679
# host name                          0.395715
# neighbourhood group                0.028265
# neighbourhood                      0.015595
# lat                                0.007797
# long                               0.007797
# country                            0.518524
# country code                       0.127682
# instant_bookable                   0.102340
# cancellation_policy                0.074075
# room type                          0.000000
# Construction year                  0.208579
# price                              0.240743
# service fee                        0.266084
# minimum nights                     0.398639
# number of reviews                  0.178364
# last review                       15.490404
# reviews per month                 15.476759
# ...

# %%
#some columns to dro
data.drop(columns=['id','reviews per month','review rate number', 'calculated host listings count','availability 365', 'house_rules', 'license'],inplace=True)

# %%
# is there any missing values present in the dataset
data.isnull().sum()
# Out:
# NAME                        250
# host id                       0
# host_identity_verified      289
# host name                   406
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              409
# number of reviews           183
# last review               15893
# dtype: int64

# %%
# renaming the column in a way
data.rename(columns={'NAME':'Name'},inplace=True)

# %%
#first 5 rows of the dataset 
data.head()
# Out:
#                                                Name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                               NaN  85098326012
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country country code instant_bookable  \
# 0  40.64749 -73.97237  United States           US            False
# ...

# %%
# finding the duplicated values in the dataset
data.duplicated().sum()
# Out:
# 541

# %%
# dropping the duplicated values
data.drop_duplicates(inplace=True)

# %%
# after dropping the duplicated values
data.duplicated().sum()
# Out:
# 0

# %%
# is there any missing values present in the dataset
data.isna().sum()
# Out:
# Name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
# drop the last review column from the dataset
data.drop(columns=['last review'],inplace=True)

# %%
# dropping the null values from the dataset
data=data.dropna()

# %%
# after dropping the null values from the dataset
data.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# dtype: int64

# %%
#first 5 rows of the dataset
data.head()
# Out:
#                                                Name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country code instant_bookable  \
# ...

# %%
# converting the price column value from str data type to int data type
# first removing the $ sign with empty
data['price']=data['price'].str.replace('$','')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1852\718994821.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price']=data['price'].str.replace('$','')

# %%
# first removing the , sign with empty
data['price']=data['price'].str.replace(',','')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1852\1482994555.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price']=data['price'].str.replace(',','')

# %%
#converting the price column value from str data type to int data type
data['price']=data['price'].astype(int)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1852\1079292653.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price']=data['price'].astype(int)

# %%
# checking if the column is converting to int type or not
data['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 99342 entries, 0 to 102040
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 99342 non-null  int32
# dtypes: int32(1)
# memory usage: 1.1 MB

# %%
#first removing the $ sign with empty
data['service fee']=data['service fee'].str.replace('$','')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1852\2132313858.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['service fee']=data['service fee'].str.replace('$','')

# %%
#converting the price column value from str data type to int data type
data['service fee']=data['service fee'].astype(int)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1852\3147830359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['service fee']=data['service fee'].astype(int)

# %%
#first 5 rows of the dataset
data.head()
# Out:
#                                                Name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country code instant_bookable  \
# ...

# %%
# check the instant_bookable column value counts figure
data['instant_bookable'].value_counts()
# Out:
# instant_bookable
# False    49878
# True     49464
# Name: count, dtype: int64

# %%
# converting instant_bookable columns true or false to 1 and 0
data['instant_bookable'] = data['instant_bookable'].apply(lambda x: 1 if x==True else 0)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1852\3661588464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['instant_bookable'] = data['instant_bookable'].apply(lambda x: 1 if x==True else 0)

# %%
# check the first 5 rows of the dataset
data.head()
# Out:
#                                                Name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country code  instant_bookable  \
# ...

# %%
data.reset_index(inplace=True)

# %%
# check the first 5 rows of the dataset
data.head()
# Out:
#                                                Name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 2               verified    Lyndon           Manhattan         East Harlem
# 3               verified  Michelle           Manhattan         Murray Hill
# 4            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country code  instant_bookable  \
# ...

# %%
data.drop(columns=['level_0','index'],inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1852\3564092082.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['level_0','index'],inplace=True)

# %%
data.to_csv("C:/Users/User/Desktop/Cleaned_Airbnb_Open_Data.csv")

# %%
data.to_excel("C:/Users/User/Desktop/Cleaned_Airbnb_Open_Data.xlsx")
